# %% [markdown]
# ### _Семенов Кирилл, БКЛ162_

# %%
import os, re
from string import punctuation
import numpy as np
import json
from collections import Counter
from pprint import pprint
punct = set(punctuation)
from sklearn.metrics import classification_report

from difflib import get_close_matches

import textdistance

import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances

# %%
corpus = [sent.split() for sent in open('corpus_ng.txt', encoding='utf8').read().splitlines()]

# %%
WORDS = Counter()
for sent in corpus:
    WORDS.update(sent)

vocab = list(WORDS.keys())
id2word = {i:word for i, word in enumerate(vocab)}

vec = TfidfVectorizer(analyzer='char', ngram_range=(1,1))
X = vec.fit_transform(vocab)

# %%
vec
# Out:
# TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
def get_closest_hybrid_match(text, X, vec, metric=textdistance.levenshtein, TOPN=3):
    v = vec.transform([text])
    similarities = cosine_distances(v, X)
    topn = similarities.argsort()[0][:TOPN]
    candidates = [id2word[top] for top in topn]
    similarities = Counter()
    for word in candidates:
        similarities[word] = metric.normalized_similarity(text, word) 
    
    return similarities.most_common(1)[0]

# %%
# %%time
get_closest_hybrid_match('Моксв', X, vec)
# Out:
# Wall time: 84.8 ms
# ('москва', 0.33333333333333337)

# %%
bad = open('sents_with_mistakes.txt', encoding='utf8').read().splitlines()
true = open('correct_sents.txt', encoding='utf8').read().splitlines()

def align_words(sent_1, sent_2):
    tokens_1 = sent_1.lower().split()
    tokens_2 = sent_2.lower().split()
    
    tokens_1 = [re.sub('(^\W+|\W+$)', '', token) for token in tokens_1 if (set(token)-punct)]
    tokens_2 = [re.sub('(^\W+|\W+$)', '', token) for token in tokens_2 if (set(token)-punct)]
    
    return list(zip(tokens_1, tokens_2))

# %%
correct = 0
total = 0
bad_corrections = []
for i in range(200):
    word_pairs = align_words(true[i], bad[i])
    for pair in word_pairs:
        
        predicted = get_closest_hybrid_match(pair[1], X, vec)[0]
        if predicted == pair[0]:
            correct += 1
        else:
            bad_corrections.append((predicted,pair[0]))
        total += 1
    if not i % 10:
        print(i)
        print(correct/total)
# Out:
# 0
# 0.5333333333333333
# 10
# 0.7615384615384615
# 20
# 0.7748917748917749
# 30
# 0.7702020202020202
# 40
# 0.7680311890838206
# 50
# 0.7761674718196457
# 60
# 0.7666666666666667
# 70
# 0.7747524752475248
# 80
# 0.7736450584484591
# 90
# 0.7740667976424361
# 100
# 0.7724014336917563
# 110
# 0.7766582703610412
# 120
# 0.7811291569992266
# 130
# 0.7794871794871795
# 140
# 0.7778537252221462
# 150
# 0.7870722433460076
# 160
# 0.7871462264150944
# 170
# 0.7883211678832117
# 180
# 0.7868589743589743
# 190
# 0.7890781563126252

# %%
print('the ratio of correct corrections: '+str(correct/total))
# Out:
# the ratio of correct corrections: 0.7927710843373494

# %% [markdown]
# ### смотрим на ошибки:

# %%
bad_corrections
# Out:
# [('симпатичный', 'симпатичнейшее'),
#  ('шпионской', 'шпионское'),
#  ('гламур', 'гламурный'),
#  ('бонди', 'бонда'),
#  ('superjet', 'superheadz'),
#  ('ap', 'clap'),
#  ('tamer', 'camera'),
#  ('стояния', 'поясним'),
#  ('ополчатся', 'получатся'),
#  ('язычка', 'язычки'),
#  ('милы', 'милые'),
#  ('нащокина', 'насчет'),
#  ('чавес', 'чавеса'),
#  ('основа', 'основная'),
#  ('попавшие', 'попавшим'),
#  ('поисково-спасательных', 'аварийно-спасательных'),
#  ('краснов', 'напрасно'),
#  ('общем', 'в'),
#  ('как', 'общем'),
#  ('вы', 'как'),
#  ('знаете', 'вы'),
#  ('из', 'знаете'),
#  ('моего', 'из'),
#  ('не', 'моего'),
#  ('давнего', 'недавнего'),
#  ('пропал', 'пропажу'),
#  ('щекам', 'ящика'),
#  ('почте', 'почте.ру'),
#  ('хорошей', 'хорошо'),
#  ('выход', 'выходных'),
#  ('крите', 'рите'),
#  ('датам', 'потому'),
#  ('штат', 'что'),
#  ('упреждать', 'переждать'),
#  ('дубрава', 'дубраве'),
#  ('алюминия', 'люминала'),
#  ('тыка', 'повтыкав'),
#  ('летным', 'билетным'),
#  ('касса', 'кассам'),
#  ('тото', 'что-то'),
#  ('тамошний', 'мощный'),
#  ('рабочем', 'нерабочем'),
#  ('кредитов', 'кредиток'),
#  ('хорошей', 'хорошо'),
#  ('капулети', 'капулетти'),
#  ('прислуживания', 'прислужницу'),
#  ('кормилица', 'кормилицу'),
#  ('молодежи', 'молодежь'),
#  ('средняя', 'сегодня'),
#  ('тащиться', 'притащиться'),
#  ('программисты', 'программист'),
#  ('вешать', 'навешать'),
#  ('оплеуху', 'оплеух'),
#  ('пивовары', 'пивоварах'),
#  ('эта', 'это'),
#  ('успешна', 'конечно'),
#  ('1:0', '4:0'),
#  ('начальном', 'начальник'),
#  ('ожог', 'зажег'),
#  ('взрослому', 'по-взрослому'),
#  ('будущую', 'предыдущую'),
#  ('покрыты', 'покрытый'),
#  ('лег', 'слег'),
#  ('ветряные', 'ветрянка'),
#  ('подсаживался', 'подсаживается'),
#  ('шина', 'женщина'),
#  ('загружена', 'загруживаюсь'),
#  ('какие', 'какие-то'),
#  ('малолетних', 'малолетние'),
#  ('трагичности', 'трагичность'),
#  ('хихикали', 'хихикать'),
#  ('потерянном', 'потерянная'),
#  ('молодежи', 'молодежь'),
#  ('слушаю', 'ощущаю'),
#  ('монгола', 'монголоидом'),
#  ('молчал', 'молчала'),
#  ('молча', 'молчу'),
#  ('языковым', 'языковый'),
#  ('бар', 'барьер'),
#  ('чашкой', 'сашкой'),
#  ('неудобные', 'неудобны'),
#  ('плоскостях', 'плоскостопых'),
#  ('объявлялись', 'объелись'),
#  ('пицца', 'пиццы'),
#  ('спрашивая', 'расспрашивая'),
#  ('иностранцев', 'иностранцев-гостей'),
#  ('впечатление', 'впечатлении'),
#  ('обитель', 'зубодробительная'),
#  ('ребенка', 'гребенка'),
#  ('ненавистным', 'ненавистный'),
#  ('саааа', 'как'),
#  ('изводит', 'изводить'),
#  ('постамент', 'пергамент'),
#  ('смена', 'письмена'),
#  ('дорого', 'дороговато'),
#  ('тучку', 'штучка'),
#  ('оцифровать', 'расшифровать'),
#  ('самой', 'самой-то'),
#  ('стул', 'тут'),
#  ('ваще', 'вообще'),
#  ('тока', 'только'),
#  ('наверно', 'наверное'),
#  ('кишке', 'сынишке'),
#  ('покормил', 'покорми'),
#  ('шить', 'сшить'),
#  ('доделал', 'доделала'),
#  ('сяс', 'яся'),
#  ('актор', 'как-то'),
#  ('делегитимизирует', 'легитимизирует'),
#  ('общину', 'мужчину'),
#  ('озаботился', 'озаботил'),
#  ('ника', 'никогда'),
#  ('отключат', 'отключает'),
#  ('готовые', 'потовые'),
#  ('слюны', 'слюнные'),
#  ('trade', 'nettrader'),
#  ('припомнил', 'препараты'),
#  ('коза', 'варикоза'),
#  ('съезде', 'съездили'),
#  ('купи', 'купим'),
#  ('общем', 'вообще'),
#  ('пришло', 'пришлось'),
#  ('абд', 'бд'),
#  ('программирование', 'программирования'),
#  ('vision', 'navision'),
#  ('ap', 'axapta'),
#  ('спасла', 'опасался'),
#  ('ложился', 'разжился'),
#  ('экземпляров', 'экземпляром'),
#  ('снабжал', 'сабжа'),
#  ('обезумевший', 'обезумевшая'),
#  ('раскидал', 'раскидала'),
#  ('зунр', 'зубные'),
#  ('щетку', 'щетки'),
#  ('пользование', 'пользоваться'),
#  ('передовую', 'бредовую'),
#  ('оздоев', 'доев'),
#  ('грибном', 'грибной'),
#  ('оставшись', 'покатавшись'),
#  ('радуги', 'радуге'),
#  ('транслируя', 'если'),
#  ('экономика', 'экономикса'),
#  ('пчелка', 'челка'),
#  ('росла', 'отросла'),
#  ('отречься', 'стричься'),
#  ('поднимает', 'обнимает'),
#  ('основы', 'основные'),
#  ('фториды', 'эриды'),
#  ('недооценка', 'самооценка'),
#  ('движении', 'движение'),
#  ('впереди', 'спереди'),
#  ('правила', 'правило'),
#  ('бодрым', 'бодрый'),
#  ('затихали', 'приехали'),
#  ('читал', 'прочитал'),
#  ('православному', 'православном'),
#  ('расхождении', 'нисхождении'),
#  ('много', 'немного'),
#  ('тосковал', 'тосковать'),
#  ('однообразие', 'однообразия'),
#  ('открыв', 'открываю'),
#  ('написанном', 'написано'),
#  ('высыпали', 'высыпание'),
#  ('забава', 'забавен'),
#  ('тряпка', 'тряпки'),
#  ('живой', 'полуживой'),
#  ('хлам', 'хламину'),
#  ('классно', 'классная'),
#  ('тото', 'что-то'),
#  ('философско-теологический', 'философско-антропологической'),
#  ('ралли', 'валли'),
#  ('каком-нибудь', 'каком-никаком'),
#  ('напряга', 'напряге'),
#  ('осталась', 'каталась'),
#  ('огромен', 'огроменных'),
#  ('крестом', 'крестов'),
#  ('сохранит', 'сохраню'),
#  ('сыров', 'сыро'),
#  ('ваще', 'вообще'),
#  ('ато', 'ад'),
#  ('делающим', 'делающие'),
#  ('первой', 'первый'),
#  ('ника', 'никогда'),
#  ('угадаешь', 'угадаете'),
#  ('сожжено', 'позже'),
#  ('когда', 'когда-то'),
#  ('задала', 'отдала'),
#  ('прокол', 'прокорм'),
#  ('ваще', 'вообще'),
#  ('джойс', 'джойстер'),
#  ('фск', 'все'),
#  ('сан', 'сань'),
#  ('общем', 'вообще'),
#  ('похудение', 'похудения'),
#  ('оснащен', 'насчет'),
#  ('оливера', 'гулливера'),
#  ('самым', 'самый'),
#  ('свое', 'своей'),
#  ('но', 'на'),
#  ('попятными', 'попятную'),
#  ('кое-как', 'никак'),
#  ('обидел', 'обидели'),
#  ('страны', 'странным'),
#  ('рекомендация', 'рекомендации'),
#  ('порок', 'горок'),
#  ('рэм', 'ремонт'),
#  ('жест', 'жесть'),
#  ('руки-то', 'руки-ноги'),
#  ('раскинув', 'раскину'),
#  ('растопырил', 'растопырить'),
#  ('ваще', 'вообще'),
#  ('снежинки', 'снежинка'),
#  ('решен', 'еще'),
#  ('расплачиваются', 'расплющиваются')]

# %% [markdown]
# ### Метрика моего авторства - посмотреть среднее расстояние Левенштейна в ошибочно исправленных словах:

# %%
distances = 0
for pair in bad_corrections:
    d = textdistance.levenshtein(pair[0], pair[1])
    distances+=d

# %%
print('the average Levenstein distance of the wrong corrections: '+str(distances/len(bad_corrections)))
# Out:
# the average Levenstein distance of the wrong corrections: 3.2348837209302324

# %% [markdown]
# ### Вывод:
# неплохо, но можно и получше

# %% [markdown]
# ## Подправляем н-граммы:

# %%
WORDS = Counter()
for sent in corpus:
    WORDS.update(sent)

vocab = list(WORDS.keys())
id2word = {i:word for i, word in enumerate(vocab)}

vec = TfidfVectorizer(analyzer='char', ngram_range=(1,4))
X = vec.fit_transform(vocab)

# %%
correct = 0
total = 0
bad_corrections = []
for i in range(200):
    word_pairs = align_words(true[i], bad[i])
    for pair in word_pairs:
        
        predicted = get_closest_hybrid_match(pair[1], X, vec)[0]
        if predicted == pair[0]:
            correct += 1
        else:
            bad_corrections.append((predicted,pair[0]))
        total += 1
    if not i % 10:
        print(i)
        print(correct/total)
# Out:
# 0
# 0.5333333333333333
# 10
# 0.7846153846153846
# 20
# 0.7922077922077922
# 30
# 0.7929292929292929
# 40
# 0.7992202729044834
# 50
# 0.8067632850241546
# 60
# 0.7986111111111112
# 70
# 0.801980198019802
# 80
# 0.8087141339001063
# 90
# 0.8094302554027505
# 100
# 0.8064516129032258
# 110
# 0.8094038623005877
# 120
# 0.811291569992266
# 130
# 0.8095238095238095
# 140
# 0.8092959671907041
# 150
# 0.8155893536121673
# 160
# 0.8154481132075472
# 170
# 0.815272318921954
# 180
# 0.8135683760683761
# 190
# 0.814629258517034

# %%
print('the ratio of correct corrections: '+str(correct/total))
# Out:
# the ratio of correct corrections: 0.8178313253012048

# %%
distances = 0
for pair in bad_corrections:
    d = textdistance.levenshtein(pair[0], pair[1])
    distances+=d

# %%
print('the average Levenstein distance of the wrong corrections: '+str(distances/len(bad_corrections)))
# Out:
# the average Levenstein distance of the wrong corrections: 2.5793650793650795

# %% [markdown]
# ### Вывод:
# Очень хорошее улучшение, целых два процента! И расстояние Левенштейна сократилось!
#
# Но посмотрим на ошибки:

# %%
bad_corrections
# Out:
# [('симпатичный', 'симпатичнейшее'),
#  ('шпионской', 'шпионское'),
#  ('гламур', 'гламурный'),
#  ('бонди', 'бонда'),
#  ('superjet', 'superheadz'),
#  ('ap', 'clap'),
#  ('tamer', 'camera'),
#  ('стояния', 'поясним'),
#  ('ополчатся', 'получатся'),
#  ('язычка', 'язычки'),
#  ('милы', 'милые'),
#  ('нащокина', 'насчет'),
#  ('чавес', 'чавеса'),
#  ('основа', 'основная'),
#  ('попавшие', 'попавшим'),
#  ('поисково-спасательных', 'аварийно-спасательных'),
#  ('краснов', 'напрасно'),
#  ('общем', 'в'),
#  ('как', 'общем'),
#  ('вы', 'как'),
#  ('знаете', 'вы'),
#  ('из', 'знаете'),
#  ('моего', 'из'),
#  ('не', 'моего'),
#  ('давнего', 'недавнего'),
#  ('пропал', 'пропажу'),
#  ('щекам', 'ящика'),
#  ('почте', 'почте.ру'),
#  ('хорошей', 'хорошо'),
#  ('выход', 'выходных'),
#  ('крите', 'рите'),
#  ('датам', 'потому'),
#  ('штат', 'что'),
#  ('упреждать', 'переждать'),
#  ('дубрава', 'дубраве'),
#  ('алюминия', 'люминала'),
#  ('тыка', 'повтыкав'),
#  ('летным', 'билетным'),
#  ('касса', 'кассам'),
#  ('тото', 'что-то'),
#  ('тамошний', 'мощный'),
#  ('рабочем', 'нерабочем'),
#  ('кредитов', 'кредиток'),
#  ('хорошей', 'хорошо'),
#  ('капулети', 'капулетти'),
#  ('прислуживания', 'прислужницу'),
#  ('кормилица', 'кормилицу'),
#  ('молодежи', 'молодежь'),
#  ('средняя', 'сегодня'),
#  ('тащиться', 'притащиться'),
#  ('программисты', 'программист'),
#  ('вешать', 'навешать'),
#  ('оплеуху', 'оплеух'),
#  ('пивовары', 'пивоварах'),
#  ('эта', 'это'),
#  ('успешна', 'конечно'),
#  ('1:0', '4:0'),
#  ('начальном', 'начальник'),
#  ('ожог', 'зажег'),
#  ('взрослому', 'по-взрослому'),
#  ('будущую', 'предыдущую'),
#  ('покрыты', 'покрытый'),
#  ('лег', 'слег'),
#  ('ветряные', 'ветрянка'),
#  ('подсаживался', 'подсаживается'),
#  ('шина', 'женщина'),
#  ('загружена', 'загруживаюсь'),
#  ('какие', 'какие-то'),
#  ('малолетних', 'малолетние'),
#  ('трагичности', 'трагичность'),
#  ('хихикали', 'хихикать'),
#  ('потерянном', 'потерянная'),
#  ('молодежи', 'молодежь'),
#  ('слушаю', 'ощущаю'),
#  ('монгола', 'монголоидом'),
#  ('молчал', 'молчала'),
#  ('молча', 'молчу'),
#  ('языковым', 'языковый'),
#  ('бар', 'барьер'),
#  ('чашкой', 'сашкой'),
#  ('неудобные', 'неудобны'),
#  ('плоскостях', 'плоскостопых'),
#  ('объявлялись', 'объелись'),
#  ('пицца', 'пиццы'),
#  ('спрашивая', 'расспрашивая'),
#  ('иностранцев', 'иностранцев-гостей'),
#  ('впечатление', 'впечатлении'),
#  ('обитель', 'зубодробительная'),
#  ('ребенка', 'гребенка'),
#  ('ненавистным', 'ненавистный'),
#  ('саааа', 'как'),
#  ('изводит', 'изводить'),
#  ('постамент', 'пергамент'),
#  ('смена', 'письмена'),
#  ('дорого', 'дороговато'),
#  ('тучку', 'штучка'),
#  ('оцифровать', 'расшифровать'),
#  ('самой', 'самой-то'),
#  ('стул', 'тут'),
#  ('ваще', 'вообще'),
#  ('тока', 'только'),
#  ('наверно', 'наверное'),
#  ('кишке', 'сынишке'),
#  ('покормил', 'покорми'),
#  ('шить', 'сшить'),
#  ('доделал', 'доделала'),
#  ('сяс', 'яся'),
#  ('актор', 'как-то'),
#  ('делегитимизирует', 'легитимизирует'),
#  ('общину', 'мужчину'),
#  ('озаботился', 'озаботил'),
#  ('ника', 'никогда'),
#  ('отключат', 'отключает'),
#  ('готовые', 'потовые'),
#  ('слюны', 'слюнные'),
#  ('trade', 'nettrader'),
#  ('припомнил', 'препараты'),
#  ('коза', 'варикоза'),
#  ('съезде', 'съездили'),
#  ('купи', 'купим'),
#  ('общем', 'вообще'),
#  ('пришло', 'пришлось'),
#  ('абд', 'бд'),
#  ('программирование', 'программирования'),
#  ('vision', 'navision'),
#  ('ap', 'axapta'),
#  ('спасла', 'опасался'),
#  ('ложился', 'разжился'),
#  ('экземпляров', 'экземпляром'),
#  ('снабжал', 'сабжа'),
#  ('обезумевший', 'обезумевшая'),
#  ('раскидал', 'раскидала'),
#  ('зунр', 'зубные'),
#  ('щетку', 'щетки'),
#  ('пользование', 'пользоваться'),
#  ('передовую', 'бредовую'),
#  ('оздоев', 'доев'),
#  ('грибном', 'грибной'),
#  ('оставшись', 'покатавшись'),
#  ('радуги', 'радуге'),
#  ('транслируя', 'если'),
#  ('экономика', 'экономикса'),
#  ('пчелка', 'челка'),
#  ('росла', 'отросла'),
#  ('отречься', 'стричься'),
#  ('поднимает', 'обнимает'),
#  ('основы', 'основные'),
#  ('фториды', 'эриды'),
#  ('недооценка', 'самооценка'),
#  ('движении', 'движение'),
#  ('впереди', 'спереди'),
#  ('правила', 'правило'),
#  ('бодрым', 'бодрый'),
#  ('затихали', 'приехали'),
#  ('читал', 'прочитал'),
#  ('православному', 'православном'),
#  ('расхождении', 'нисхождении'),
#  ('много', 'немного'),
#  ('тосковал', 'тосковать'),
#  ('однообразие', 'однообразия'),
#  ('открыв', 'открываю'),
#  ('написанном', 'написано'),
#  ('высыпали', 'высыпание'),
#  ('забава', 'забавен'),
#  ('тряпка', 'тряпки'),
#  ('живой', 'полуживой'),
#  ('хлам', 'хламину'),
#  ('классно', 'классная'),
#  ('тото', 'что-то'),
#  ('философско-теологический', 'философско-антропологической'),
#  ('ралли', 'валли'),
#  ('каком-нибудь', 'каком-никаком'),
#  ('напряга', 'напряге'),
#  ('осталась', 'каталась'),
#  ('огромен', 'огроменных'),
#  ('крестом', 'крестов'),
#  ('сохранит', 'сохраню'),
#  ('сыров', 'сыро'),
#  ('ваще', 'вообще'),
#  ('ато', 'ад'),
#  ('делающим', 'делающие'),
#  ('первой', 'первый'),
#  ('ника', 'никогда'),
#  ('угадаешь', 'угадаете'),
#  ('сожжено', 'позже'),
#  ('когда', 'когда-то'),
#  ('задала', 'отдала'),
#  ('прокол', 'прокорм'),
#  ('ваще', 'вообще'),
#  ('джойс', 'джойстер'),
#  ('фск', 'все'),
#  ('сан', 'сань'),
#  ('общем', 'вообще'),
#  ('похудение', 'похудения'),
#  ('оснащен', 'насчет'),
#  ('оливера', 'гулливера'),
#  ('самым', 'самый'),
#  ('свое', 'своей'),
#  ('но', 'на'),
#  ('попятными', 'попятную'),
#  ('кое-как', 'никак'),
#  ('обидел', 'обидели'),
#  ('страны', 'странным'),
#  ('рекомендация', 'рекомендации'),
#  ('порок', 'горок'),
#  ('рэм', 'ремонт'),
#  ('жест', 'жесть'),
#  ('руки-то', 'руки-ноги'),
#  ('раскинув', 'раскину'),
#  ('растопырил', 'растопырить'),
#  ('ваще', 'вообще'),
#  ('снежинки', 'снежинка'),
#  ('решен', 'еще'),
#  ('расплачиваются', 'расплющиваются'),
#  ('докладчик', 'асфальтоукладчик'),
#  ('проясненной', 'проясненным'),
#  ('бойцов', 'бойцовский'),
#  ('флуктуации', 'флуктуировала'),
#  ('атомы', 'симптомы'),
#  ('зажато', 'зажатия'),
#  ('пупка', 'пупковой'),
#  ('рыжим', 'грыжи'),
#  ('пот', 'потому'),
#  ('мразь', 'разве'),
#  ('ось', 'пришлось'),
#  ('унывака', 'унываю'),
#  ('поговорила', 'договорилась'),
#  ('ломоть', 'посмотреть'),
#  ('снежкина', 'снежки'),
#  ('чернил', 'чернила'),
#  ('вырванных', 'вырваны'),
#  ('гоните', 'начните'),
#  ('погреба', 'он'),
#  ('ее', 'выгребает'),
#  ('из', 'ее'),
#  ('под', 'из-под'),
#  ('хвоста', 'хвостами'),
#  ('было', 'не'),
#  ('никогда', 'было'),
#  ('любви', 'никогда'),
#  ('то', 'любви-то'),
#  ('жуков', 'мужиков'),
#  ('утренний', 'утренние'),
#  ('линке', 'линк'),
#  ('монитор', 'мониторы'),
#  ('начальном', 'начальник'),
#  ('кружился', 'дружился'),
#  ('начальницей', 'начальнице'),
#  ('таит', 'зайти'),
#  ('вконтакте', 'вконтакт'),
#  ('посеяна', 'потеряна'),
#  ('ненавидя', 'ненавидишь'),
#  ('мыслящим', 'мыслящая'),
#  ('мишу', 'мишуру'),
#  ('прицеливания', 'отбеливания'),
#  ('креатив', 'креативят'),
#  ('средняя', 'сегодня'),
#  ('вредна', 'свредничала'),
#  ('продавщицы', 'продавщицу'),
#  ('перевешивали', 'перевешивать'),
#  ('весит', 'бесит'),
#  ('увольнять', 'увольняться'),
#  ('патагонии', 'патагонию'),
#  ('гондураса', 'гондурас'),
#  ('серов', 'серой'),
#  ('накидки', 'накидке'),
#  ('рисунков', 'рисунком'),
#  ('умалчивает', 'мальчик'),
#  ('упоение', 'упоением'),
#  ('мухиной', 'сухинова'),
#  ('продолжения', 'продолжение'),
#  ('изумрудный', 'изумрудного'),
#  ('имхофа', 'имхо'),
#  ('кость', 'бякость'),
#  ('потов', 'потому'),
#  ('взывал', 'взываю'),
#  ('марионетка', 'марионетки'),
#  ('спичечный', 'спичечного'),
#  ('расовой', 'тасовать'),
#  ('ведущий', 'следующий'),
#  ('основным', 'основной'),
#  ('общем', 'вообще'),
#  ('фск', 'все'),
#  ('опаздывал', 'опаздываю'),
#  ('средняя', 'сегодня'),
#  ('саааа', 'страшно'),
#  ('кроме', 'окромя'),
#  ('успешна', 'конечно'),
#  ('пна', 'компания'),
#  ('фар', 'фарш'),
#  ('сеня', 'ясеня'),
#  ('казне', 'праздник'),
#  ('встретит', 'встретиться'),
#  ('сажусь', 'нахожусь'),
#  ('непонятному', 'непонятном'),
#  ('паршивая', 'паршивое'),
#  ('закипаю', 'закипания'),
#  ('пайла', 'сайлау'),
#  ('ваще', 'вообще'),
#  ('наркотиков', 'наркотикоподобен'),
#  ('возни', 'возню'),
#  ('брыкающаяся', 'брыкаться'),
#  ('уезжать', 'визжать'),
#  ('цитировать', 'медитировать'),
#  ('обучено', 'обычно'),
#  ('аптеки', 'стеки'),
#  ('садится', 'садиться'),
#  ('залпов', 'залпы'),
#  ('княжество', 'княжестве'),
#  ('беглое', 'беглянок'),
#  ('серебряному', 'серебряном'),
#  ('средняя', 'сегодня'),
#  ('календари', 'календарику'),
#  ('выводов', 'выводок'),
#  ('абрикос', 'чудябриков'),
#  ('мастерски', 'мастерскую'),
#  ('возить', 'отвозить'),
#  ('решен', 'еще'),
#  ('скепсис', 'пепси'),
#  ('обслуживание', 'ослуживание'),
#  ('безупречно', 'безупречное'),
#  ('ищите', 'ищете'),
#  ('какова', 'какого'),
#  ('ена', 'района'),
#  ('начало', 'сначала'),
#  ('всяк', 'всякий'),
#  ('вольно', 'довольно'),
#  ('милы', 'милые'),
#  ('гоша', 'угощали'),
#  ('скрыл', 'открыл'),
#  ('подделали', 'подделанная'),
#  ('аутентичная', 'неаутентична'),
#  ('подделка', 'подделку'),
#  ('митинги', 'постинги'),
#  ('вкусном', 'вкусному'),
#  ('завтрак', 'завтраку'),
#  ('познакомит', 'познакомиться'),
#  ('большое', 'большой'),
#  ('загорелись', 'загорелась'),
#  ('ольга', 'шульга'),
#  ('марины', 'зимариным'),
#  ('незнамо', 'не'),
#  ('ходить', 'знаю'),
#  ('на', 'ходить'),
#  ('море', 'на'),
#  ('делать', 'море'),
#  ('ремонт', 'делать'),
#  ('кого', 'ремонт'),
#  ('будь', 'кого-нибудь'),
#  ('ося', 'лосяра'),
#  ('общем', 'вообще'),
#  ('удивленный', 'осчастливленный'),
#  ('альбомов', 'альбомом'),
#  ('левон', 'левонтием'),
#  ('тяжелой', 'анжелой'),
#  ('оны', 'оным'),
#  ('договариваясь', 'втариваясь'),
#  ('коньяк', 'коньяком'),
#  ('школой', 'колой'),
#  ('тряпка', 'тряпки'),
#  ('чт', 'что'),
#  ('поведет', 'поведайте'),
#  ('плит', 'плиз'),
#  ('тока', 'только'),
#  ('дай', 'сдай'),
#  ('точным', 'обычным'),
#  ('мыло', 'мылом'),
#  ('сушить', 'сушит'),
#  ('гегель', 'гель'),
#  ('потянулись', 'притянулись'),
#  ('сгибается', 'нагибается'),
#  ('иконку', 'иконка'),
#  ('начальном', 'начальник'),
#  ('читаем', 'читаемость'),
#  ('немана', 'неманичей'),
#  ('жальче', 'мальчики'),
#  ('порше', 'хорошее'),
#  ('отмоют', 'потому')]

# %% [markdown]
# Очень много чередований внутри словоформ одной лексемы, но бывает и путаница между частями речи. Попробуем это устранить.

# %% [markdown]
# ## Подправляем код, добавив pymorphy:

# %%
import pymorphy2
from pymorphy2 import MorphAnalyzer

# %%
def pos_finder(w):
    morph = MorphAnalyzer()
    ana = morph.parse(w)
    pos = str(ana[0].tag).split(',')[0]
    return pos

def get_closest_hybrid_match_2(text, X, vec, metric=textdistance.levenshtein, TOPN=3):
    text_pos = pos_finder(text)
    v = vec.transform([text])
    similarities = cosine_distances(v, X)
    topn = similarities.argsort()[0][:TOPN]
    #print(topn)
    candidates = []
    pre_candidates = [id2word[top] for top in topn]
    for c in pre_candidates:
        c_pos = pos_finder(c)
        if c_pos == text_pos:
            candidates.append(c)
    if len(candidates) == 0:
        candidates = pre_candidates
    similarities = Counter()
    for word in candidates:
        similarities[word] = metric.normalized_similarity(text, word) 
    
    return similarities.most_common(1)[0]

# %%
correct = 0
total = 0
bad_corrections = []
for i in range(200):
    word_pairs = align_words(true[i], bad[i])
    #print(word_pairs)
    for pair in word_pairs:
        
        predicted = get_closest_hybrid_match_2(pair[1], X, vec)[0]
        if predicted == pair[0]:
            #print('good: '+predicted+' '+pair[0])
            correct += 1
        else:
            bad_corrections.append((predicted,pair[0]))
        total += 1
    if not i % 10:
        print(i)
        print(correct/total)
# Out:
# 0
# 0.5333333333333333
# 10
# 0.7769230769230769
# 20
# 0.7878787878787878
# 30
# 0.7904040404040404
# 40
# 0.797270955165692
# 50
# 0.8051529790660226
# 60
# 0.7972222222222223
# 70
# 0.7970297029702971
# 80
# 0.8023379383634431
# 90
# 0.8015717092337917
# 100
# 0.7983870967741935
# 110
# 0.8001679261125105
# 120
# 0.8020108275328693
# 130
# 0.8
# 140
# 0.7983595352016405
# 150
# 0.8054499366286438
# 160
# 0.8054245283018868
# 170
# 0.8051656372824256
# 180
# 0.8023504273504274
# 190
# 0.8041082164328658

# %%
print('the ratio of correct corrections: '+str(correct/total))
# Out:
# the ratio of correct corrections: 0.8067469879518072

# %%
distances = 0
for pair in bad_corrections:
    d = textdistance.levenshtein(pair[0], pair[1])
    distances+=d

print('the average Levenstein distance of the wrong corrections: '+str(distances/len(bad_corrections)))
# Out:
# the average Levenstein distance of the wrong corrections: 2.7231920199501247

# %% [markdown]
# ### Вывод:
# качество колеблется на том же уровне, даже немного похуже.
